# %% [markdown]
# Датасет - corporate_work_hours_productivity.csv

# %% [markdown]
# # Задание: Анализ и моделирование на данных 📊
#
# ## 1. Загрузка и подготовка данных 📥
# Загрузите датасет и выполните предварительную обработку данных:
#
# - Выведите количество строк и признаков.
# - Обработайте пропуски, если они есть.
# - Признак **Job_Level** является таргетом, сделайте бинарным: если значение "senior", то 1, иначе 0.
#
# ## 2. EDA (Анализ данных) 🔍
# - Сколько в среднем работают те, у кого хорошее соотношение work-life balance? ⚖️
# - Кто выполняет больше тасков: те, кто работает удаленно или нет? 🏠📈
# - Какой департамент больше удовлетворен работой в среднем? 🏢💼
# - У какого департамента больше встреч за неделю? 📅
#
# ## 3. Разделение данных и обучение моделей 🧑‍🏫
# 1. Разбейте данные на тренировочную и тестовую выборки (80/20).
# 2. Сделайте **label encoding** для категориальных признаков.
# 3. Обучите логистическую регрессию:
#    - Обычная логистическая регрессия.
#    - Логистическая регрессия с L1, L2 и Elastic Net регуляризацией.
# 4. Составьте сравнительную таблицу с **Train AUC**, **Test AUC** и **Train-Test Difference AUC**.
#
# ## 4. Обучение и ансамблирование моделей 🌳
# 1. Обучите **Decision Tree** и **KNN Classifiers**.
# 2. Создайте ансамбль с использованием метода **Bagging**:
#    - Лучшую модель из предыдущего шага.
#    - Decision Tree.
#    - KNN.
# 3. Оцените качество моделей по сравнению с **Logistic Regression**.
#
# ## 5. Модели с использованием Catboost, RandomForest, LightGBM и Stacking 🏆
# 1. Обучите модели **Catboost**, **RandomForest** и **LightGBM** на тех же данных.
# 2. Примените **stacking** с метамоделью **Logistic Regression**:
#    - Используйте все признаки датасета + новые признаки.
#    - Разбейте тренировочные данные на 70/30 для обучения метамодели.
#    - AUC рассчитывайте на исходном тесте.
#
# ## 6. Анализ работы модели по департаментам 🔬
# Проанализируйте, для какого департамента модель работает хуже всего:
# - Найдите категорию, где **AUC** ниже всего или разница между **train** и **test** максимальна в этой категории.
# - Нарисуйте для этой категоии **KDE** на тренировочных и тестовых данных для 3 самых важных числовых признаков модели с количеством уникальных значений больше 50 (если такие имеются):
#   - На одном графике должны быть **2 KDE** (для train и test) для каждого признака.
#   - Итого: 3 графика (не считая **Feature Importance**).
#
# ## 7. Генерация признаков и отбор на основе Feature Importance ⚙️
# 1. Сгенерируйте новые признаки всеми подходами, изученными на занятиях.
# 2. Сделайте **отбор 20 признаков** на основе **Feature Importance**.
# 3. Обучите модель **Catboost** на новых признаках и сравните с моделью **Stacking**.
# 4. Визуализируйте обучение **Catboost** с параметром `plot=True`.
#
# ## 8. Подбор гиперпараметра для Catboost 🔧
# 1. Сделайте подбор гиперпараметра **iterations** для модели **Catboost**.
# 2. Визуализируйте кривые обучения, чтобы найти количество деревьев, при котором модель переобучается.
#    - На графике отображайте **Train AUC** и **Test AUC**.
#    - Покажите, как изменяется **Bias-Variance Tradeoff** при увеличении количества деревьев.
#
# ---
#
# Удачи с выполнением задания! 🚀
